# %%
import sys
sys.path.append("..")
import era5openmeteo as om
import time

startdate = "1990-01-01"
enddate = "2024-12-31"
# As, Norway
latitude, longitude = (59.659,10.780) 
loc = "As"

elevation = 104
angstroma = 0.21
angstromb = 0.58
hassunshine = False

filename = f'era5_{loc}_{startdate.replace("-", "")}_{enddate.replace("-", "")}'
df = om.era5_to_dssat(latitude, longitude, startdate, enddate)
om.df_to_csv_dssat('As', f'data/met/{filename}.csv', df, latitude, longitude, elevation)

print(df)
time.sleep(120)
# Out:
# /Users/nadiatestani/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
# Out:
#           DATE  SRAD  TMAX  TMIN  RAIN  RHUM
# 0      1990001   1.0  -7.2 -11.2   0.0  79.4
# 1      1990002   1.1  -7.3 -10.0   0.0  88.9
# 2      1990003   0.4  -6.0 -10.1   0.0  86.5
# 3      1990004   0.4  -0.7  -5.6   5.8  92.9
# 4      1990005   0.7  -0.8  -3.1   0.0  93.2
# ...        ...   ...   ...   ...   ...   ...
# 12779  2024362   0.4   1.9  -0.3   0.7  99.9
# 12780  2024363   0.7   4.1  -0.2   0.0  99.3
# 12781  2024364   1.0   6.9   2.9   0.0  88.1
# 12782  2024365   0.6   3.5  -2.9   0.0  56.7
# 12783  2024366   0.5  -0.3  -3.0   5.6  66.8
#
# [12784 rows x 6 columns]
